# %%
import qiskit

# %%
qiskit.__version__
# Out:
# '2.3.0'

# %%
from qiskit_ibm_runtime import QiskitRuntimeService

service = QiskitRuntimeService(channel="ibm_quantum_platform", # ibm_cloud
                                    token= 'JmZxHDAeWrPJJ7KB3Cafyz3pIyOMeU-oc_lRoDRWXErH')
# Out:
# qiskit_runtime_service._discover_account:WARNING:2026-01-23 00:29:30,701: Loading account with the given token. A saved account will not be used.
# qiskit_runtime_service.__init__:WARNING:2026-01-23 00:29:37,310: Instance was not set at service instantiation. Free and trial plan instances will be prioritized. Based on the following filters: (tags: None, region: us-east, eu-de), and available plans: (open), the available account instances are: open-instance. If you need a specific instance set it explicitly either by using a saved account with a saved default instance or passing it in directly to QiskitRuntimeService().

# %%
QiskitRuntimeService.save_account(channel="ibm_quantum_platform",
                                  token='JmZxHDAeWrPJJ7KB3Cafyz3pIyOMeU-oc_lRoDRWXErH',
                                  overwrite=True)

# %%
backend = service.backend(name = "ibm_marrakesh")
# Out:
# qiskit_runtime_service.backends:WARNING:2026-01-23 00:35:53,475: Using instance: open-instance, plan: open

# %%
backend.num_qubits
# Out:
# 156
